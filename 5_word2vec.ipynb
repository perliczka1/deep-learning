# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# %matplotlib inline

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'originated', 'of']

# %%
type(labels)
labels.shape
# Out:
# (8, 1)

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.810803
# Nearest to war: prat, alison, goddess, transducers, asch, rochester, intakes, statistics,
# Nearest to had: connecting, miniaturization, threefold, excesses, encircled, iras, neue, shale,
# Nearest to are: djing, undertakes, psychosocial, jeter, ufo, afflicted, folding, reap,
# Nearest to as: sulfates, perkin, rabbit, discovering, alphabetically, monolingual, apply, clemency,
# Nearest to can: unrestrained, robertson, untso, tod, raman, bands, blob, ecu,
# Nearest to their: qasim, polymath, prophesied, kuo, saddened, nuances, heliogabalus, simeon,
# Nearest to use: jessie, solution, batch, fashions, maccabeus, aconcagua, plea, skeletal,
# Nearest to from: disembodied, servers, pkn, ize, fgth, reflections, devoted, sindh,
# Nearest to than: kwashiorkor, multiplicative, pause, masterpieces, tainted, ecusa, mysterious, kazaa,
# Nearest to four: composer, ariane, navier, safin, criminalized, diligence, d, shema,
# Nearest to been: polymorphic, kills, chromodynamics, totoro, aronson, publisher, korps, doubleday,
# Nearest to i: bec, cddb, dynamically, ashanti, entscheidungsproblem, routledge, chieftains, hiragana,
# Nearest to seven: apprenticed, checkmate, crts, tatars, flora, cabral, begun, dvd,
# Nearest to called: abhidharma, game, sequels, shortfalls, hutcheson, activities, embellishment, therapies,
# Nearest to into: maharashtri, cladistic, blocks, palestinian, ministries, kraftwerk, cook, fly,
# Nearest to between: belfry, ely, grafton, ship, goodnight, ritual, fancy, pis,
# Average loss at step 2000: 4.349480
# Average loss at step 4000: 3.865671
# Average loss at step 6000: 3.794856
# Average loss at step 8000: 3.684772
# Average loss at step 10000: 3.618301
# Nearest to war: prat, scholar, scriptores, hitchhiker, gliders, dory, information, lucrezia,
# Nearest to had: has, have, was, coercive, were, pda, consistent, miniaturization,
# Nearest to are: were, is, have, crannog, marries, sackville, was, smithsonian,
# Nearest to as: fianna, sulfates, chrono, loyalist, by, perkin, horizontally, mercalli,
# Nearest to can: would, may, will, could, raman, robertson, disparaging, cannot,
# Nearest to their: his, saddened, anointing, polymath, nationale, kuo, babylonia, ectopic,
# Nearest to use: dorians, aconcagua, mounting, cargo, solution, stability, minaret, jessie,
# Nearest to from: with, in, by, callixtus, for, melvins, on, rosalyn,
# Nearest to than: multiplicative, kwashiorkor, activist, henotheistic, chinaman, beige, lifestyles, troodos,
# Nearest to four: six, three, five, seven, eight, two, zero, nine,
# Nearest to been: kills, polymorphic, by, liners, had, posteriori, swaim, publisher,
# Nearest to i: we, chieftains, cddb, delian, lyre, entscheidungsproblem, rett, gough,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to called: abhidharma, word, moravians, hutcheson, vic, mayday, clyde, activities,
# Nearest to into: marched, brew, kraftwerk, cts, and, ediacaran, productivity, caucasus,
# Nearest to between: in, catholicism, ritual, wicket, thymine, ely, belfry, turbojet,
# Average loss at step 12000: 3.606845
# Average loss at step 14000: 3.571676
# Average loss at step 16000: 3.402920
# Average loss at step 18000: 3.457890
# Average loss at step 20000: 3.538799
# Nearest to war: scriptores, gliders, hitchhiker, rochester, spins, prat, margherita, birthright,
# Nearest to had: has, have, was, were, coercive, been, miniaturization, catches,
# Nearest to are: were, is, have, was, though, recalcitrant, synthesizer, be,
# Nearest to as: favorably, multiculturalism, squat, dieppe, for, enol, inv, carts,
# Nearest to can: may, would, will, could, cannot, must, to, should,
# Nearest to their: his, its, the, her, nationale, kuo, anointing, many,
# Nearest to use: jessie, batch, koffice, mounting, solution, stability, associating, commitment,
# Nearest to from: into, in, callixtus, echolocation, after, melvins, pejoratively, upon,
# Nearest to than: or, henotheistic, kwashiorkor, troodos, vil, resource, chinaman, beige,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to been: was, be, were, by, mufti, had, kippur, never,
# Nearest to i: ii, we, delian, lyre, chieftains, rett, laga, documentaries,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to called: abhidharma, untitled, hutcheson, twigs, wagons, mccullough, moravians, leda,
# Nearest to into: from, cts, marched, after, rada, by, ediacaran, kraftwerk,
# Nearest to between: with, in, turbojet, catholicism, ship, dialectical, thymine, ritual,
# Average loss at step 22000: 3.500692
# Average loss at step 24000: 3.485499
# Average loss at step 26000: 3.482981
# Average loss at step 28000: 3.484970
# Average loss at step 30000: 3.505548
# Nearest to war: rochester, spins, gliders, margherita, dory, hitchhiker, scriptores, birthright,
# Nearest to had: has, have, was, were, catches, coercive, miniaturization, subshell,
# Nearest to are: were, have, is, synthesizer, recalcitrant, be, include, although,
# Nearest to as: chrono, became, hydroxyl, when, by, inv, multiculturalism, illiberal,
# Nearest to can: may, would, will, could, cannot, must, should, might,
# Nearest to their: his, its, her, the, nationale, these, many, some,
# Nearest to use: overlooking, associating, solution, jessie, afghan, stability, mounting, objects,
# Nearest to from: into, in, after, callixtus, under, pejoratively, against, of,
# Nearest to than: henotheistic, much, or, kwashiorkor, way, troodos, interestingly, chinaman,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to been: be, become, was, were, mufti, never, by, kippur,
# Nearest to i: we, ii, frud, delian, iii, h, chieftains, flavian,
# Nearest to seven: nine, eight, five, six, four, three, zero, two,
# Nearest to called: named, untitled, abhidharma, wagons, geometrically, mccullough, hutcheson, twigs,
# Nearest to into: from, cts, after, under, in, rada, brunswick, through,
# Nearest to between: with, in, against, turbojet, on, during, tamar, thymine,
# Average loss at step 32000: 3.504223
# Average loss at step 34000: 3.498445
# Average loss at step 36000: 3.450710
# Average loss at step 38000: 3.302115
# Average loss at step 40000: 3.429077
# Nearest to war: spins, scriptores, birthright, cannibal, rochester, margherita, prat, gliders,
# Nearest to had: has, have, was, were, since, when, subshell, catches,
# Nearest to are: were, have, synthesizer, is, although, include, recalcitrant, be,
# Nearest to as: fante, when, enol, chrono, illiberal, schistosomiasis, newly, trinomial,
# Nearest to can: may, could, will, would, must, cannot, might, should,
# Nearest to their: its, his, her, the, these, some, nationale, our,
# Nearest to use: koffice, overlooking, associating, stability, mounting, solution, end, gurdjieff,
# Nearest to from: into, includes, in, through, during, of, echolocation, upon,
# Nearest to than: or, henotheistic, much, gaddis, lockyer, sociologists, way, pharmacist,
# Nearest to four: six, eight, seven, five, three, two, nine, one,
# Nearest to been: be, become, were, was, mufti, never, kippur, posteriori,
# Nearest to i: we, ii, you, t, he, they, burgundy, h,
# Nearest to seven: five, six, eight, nine, four, three, zero, two,
# Nearest to called: named, untitled, wagons, twigs, ryukyu, awry, mccullough, isothermal,
# Nearest to into: from, through, cts, out, rada, capt, nudes, evolutionary,
# Nearest to between: with, among, against, before, during, thymine, flattered, carotene,
# Average loss at step 42000: 3.434627
# Average loss at step 44000: 3.454456
# Average loss at step 46000: 3.445023
# Average loss at step 48000: 3.353493
# Average loss at step 50000: 3.381742
# Nearest to war: scriptores, birthright, margherita, spins, cannibal, gliders, erasmus, straps,
# Nearest to had: has, have, was, were, since, been, coercive, ever,
# Nearest to are: were, is, have, recalcitrant, those, include, was, hayling,
# Nearest to as: favorably, chrono, when, interdict, opioid, became, paramilitaries, repeating,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to their: his, its, her, the, some, nationale, delegate, both,
# Nearest to use: subscriber, overlooking, gurdjieff, end, hedeby, solution, heuss, mounting,
# Nearest to from: into, in, callixtus, during, through, under, after, pejoratively,
# Nearest to than: or, henotheistic, much, pharmacist, heroically, rada, sociologists, naive,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to been: become, be, was, mufti, had, were, never, posteriori,
# Nearest to i: we, you, ii, t, skyscrapers, rett, documentaries, delian,
# Nearest to seven: six, nine, eight, four, five, three, zero, one,
# Nearest to called: named, untitled, awry, used, hautes, conversely, td, ryukyu,
# Nearest to into: through, from, capt, around, evolutionary, omnipresent, condense, out,
# Nearest to between: with, among, during, against, turbojet, thymine, flattered, shortages,
# Average loss at step 52000: 3.436972
# Average loss at step 54000: 3.427699
# Average loss at step 56000: 3.439897
# Average loss at step 58000: 3.401323
# Average loss at step 60000: 3.387008
# Nearest to war: spins, birthright, margherita, scriptores, erasmus, battle, straps, gliders,
# Nearest to had: has, have, was, were, having, been, gave, coercive,
# Nearest to are: were, have, is, other, dwarves, including, synthesizer, include,
# Nearest to as: create, when, blackboard, dieppe, arouse, paramilitaries, by, meltwater,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to their: its, his, her, the, some, nationale, your, shorty,
# Nearest to use: overlooking, gurdjieff, subscriber, heuss, koffice, popularity, minaret, form,
# Nearest to from: into, through, echolocation, within, during, phosphates, against, pejoratively,
# Nearest to than: and, or, much, henotheistic, pharmacist, tukey, petite, but,
# Nearest to four: six, five, eight, three, seven, nine, zero, two,
# Nearest to been: become, be, mufti, were, ornament, had, never, posteriori,
# Nearest to i: we, you, ii, t, rimbaud, frac, he, h,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to called: named, used, untitled, considered, referred, conversely, excessively, sexton,
# Nearest to into: through, from, around, within, out, cts, evolutionary, across,
# Nearest to between: with, among, in, turbojet, flattered, visibility, peacock, against,
# Average loss at step 62000: 3.233967
# Average loss at step 64000: 3.251593
# Average loss at step 66000: 3.399426
# Average loss at step 68000: 3.393820
# Average loss at step 70000: 3.352365
# Nearest to war: birthright, margherita, battle, straps, gliders, erasmus, rochester, spins,
# Nearest to had: has, have, were, was, having, already, been, coercive,
# Nearest to are: were, have, is, although, these, include, including, be,
# Nearest to as: exterminating, favorably, when, variste, opioid, illiberal, wendy, folklore,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to their: its, his, her, the, your, our, some, shorty,
# Nearest to use: subscriber, gurdjieff, overlooking, way, stability, koffice, form, popularity,
# Nearest to from: through, into, within, melvins, during, in, callixtus, phosphates,
# Nearest to than: or, henotheistic, much, naive, and, heroically, but, petite,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to been: become, be, were, was, mufti, had, already, previously,
# Nearest to i: we, you, ii, frac, g, t, commandos, rimbaud,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to called: named, referred, used, considered, untitled, sexton, modulating, word,
# Nearest to into: through, from, within, in, cts, omnipresent, condense, around,
# Nearest to between: among, with, turbojet, qualcomm, kit, sho, thymine, within,
# Average loss at step 72000: 3.371926
# Average loss at step 74000: 3.347255
# Average loss at step 76000: 3.317974
# Average loss at step 78000: 3.351701
# Average loss at step 80000: 3.378033
# Nearest to war: birthright, straps, spins, wars, factbook, margherita, satie, battle,
# Nearest to had: has, have, were, was, having, been, already, coercive,
# Nearest to are: were, have, is, include, although, recalcitrant, these, those,
# Nearest to as: radix, summon, theotokos, exterminating, illiberal, multicast, karlsruhe, carts,
# Nearest to can: could, may, will, would, should, must, might, cannot,
# Nearest to their: its, his, her, our, your, the, shorty, these,
# Nearest to use: way, notification, bayonne, schellenberg, overlooking, form, repressive, magdalena,
# Nearest to from: through, into, callixtus, under, in, by, during, after,
# Nearest to than: henotheistic, much, or, but, and, while, naive, petite,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to been: become, be, had, mufti, were, was, already, never,
# Nearest to i: we, you, ii, g, t, iii, frac, rimbaud,
# Nearest to seven: eight, five, six, four, nine, three, zero, one,
# Nearest to called: named, considered, referred, known, used, untitled, sexton, isothermal,
# Nearest to into: through, from, within, around, across, omnipresent, under, evolutionary,
# Nearest to between: among, with, turbojet, within, nausica, over, kit, haig,
# Average loss at step 82000: 3.405732
# Average loss at step 84000: 3.407419
# Average loss at step 86000: 3.387616
# Average loss at step 88000: 3.353474
# Average loss at step 90000: 3.360255
# Nearest to war: straps, wars, margherita, birthright, during, prat, factbook, andriessen,
# Nearest to had: has, have, was, were, having, already, been, would,
# Nearest to are: were, is, these, include, have, although, those, recalcitrant,
# Nearest to as: illiberal, exterminating, digger, summon, radix, wearable, wendy, meltwater,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to their: its, his, her, your, our, the, shorty, my,
# Nearest to use: support, popularity, overlooking, change, soriano, way, stability, because,
# Nearest to from: through, into, under, during, callixtus, phosphates, including, melvins,
# Nearest to than: henotheistic, much, naive, loveland, endoplasmic, tukey, or, no,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to been: become, be, was, mufti, already, had, were, being,
# Nearest to i: we, ii, g, frac, you, t, iii, r,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to called: named, considered, referred, used, sexton, known, isothermal, miskelley,
# Nearest to into: through, from, around, within, under, across, omnipresent, capt,
# Nearest to between: among, with, turbojet, within, against, griffith, during, over,
# Average loss at step 92000: 3.398496
# Average loss at step 94000: 3.252739
# Average loss at step 96000: 3.358337
# Average loss at step 98000: 3.244557
# Average loss at step 100000: 3.357283
# Nearest to war: wars, battle, straps, margherita, factbook, birthright, scriptores, maximizing,
# Nearest to had: has, have, was, having, were, since, is, took,
# Nearest to are: were, have, these, those, is, recalcitrant, although, be,
# Nearest to as: like, remedied, when, vilhelm, fante, khazar, intrusion, chiral,
# Nearest to can: may, could, will, must, should, would, might, cannot,
# Nearest to their: its, his, your, her, our, the, shorty, these,
# Nearest to use: support, instructive, overlooking, mantras, sense, popularity, heuss, nachrichten,
# Nearest to from: into, through, in, melvins, during, echolocation, at, of,
# Nearest to than: or, henotheistic, much, and, tukey, middleware, even, naive,
# Nearest to four: seven, six, five, eight, nine, three, zero, two,
# Nearest to been: become, be, was, mufti, already, ever, ornament, were,
# Nearest to i: we, you, ii, frac, they, commandos, iii, t,
# Nearest to seven: eight, nine, four, six, five, three, zero, two,
# Nearest to called: named, referred, used, untitled, considered, known, symptom, sexton,
# Nearest to into: through, from, within, across, around, under, in, cts,
# Nearest to between: among, with, turbojet, over, shortages, against, qualcomm, peacock,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# New function generating batch:

# %%
data_index = 0

def generate_batch_CBOW(batch_rows, batch_cols, skip_window):
  global data_index
  #assert batch_size % num_skips == 0
  assert batch_cols <= 2 * skip_window
  labels = np.ndarray(shape=(batch_rows,1), dtype=np.int32)
  batch = np.ndarray(shape=(batch_rows, batch_cols), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_rows):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    labels[i] = buffer[skip_window]
    for j in range(batch_cols):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i, j] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

reverse_dictionary_f = np.vectorize(lambda x: reverse_dictionary[x])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_rows=8, batch_cols=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', reverse_dictionary_f(batch))
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['as' 'anarchism']
#  ['a' 'originated']
#  ['as' 'term']
#  ['of' 'a']
#  ['term' 'abuse']
#  ['of' 'first']
#  ['abuse' 'used']
#  ['against' 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['term' 'a' 'originated' 'anarchism']
#  ['as' 'of' 'originated' 'term']
#  ['as' 'abuse' 'of' 'a']
#  ['a' 'abuse' 'term' 'first']
#  ['first' 'of' 'used' 'term']
#  ['used' 'against' 'abuse' 'of']
#  ['against' 'first' 'abuse' 'early']
#  ['early' 'first' 'used' 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Graph for CBOW model:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
cont_len = 2 # How many elements in the context for one label
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, cont_len])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed_sum = tf.reduce_sum(embed, reduction_indices=1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed_sum,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# Run model:

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(batch_size, cont_len, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.482392
# Nearest to will: impacted, ohlin, grahame, aggravated, busing, confederacy, hurdle, spreading,
# Nearest to its: vidzeme, pathologist, download, ancillary, parliament, maelstrom, objections, src,
# Nearest to he: modulus, kaohsiung, tsiolkovsky, fic, nibelungenlied, principle, grievous, clair,
# Nearest to american: roar, louie, dinosaurs, hinnom, asser, harnesses, learner, installations,
# Nearest to only: scholz, browsers, traders, lsd, daughter, pythagoreans, gls, ladders,
# Nearest to into: pathologic, afonso, hero, extraordinarily, composers, reclusive, contras, burt,
# Nearest to be: unbridled, cognitive, clicking, capcom, comprises, coordination, circuitry, communicates,
# Nearest to in: segmentata, soundtrack, ronaldo, flip, adverbial, harper, eternally, jolley,
# Nearest to their: halls, regress, wheelbase, murphy, businessweek, ubiquitous, eastwood, marr,
# Nearest to there: zar, unmop, polymerization, cond, fenton, khrushchev, belated, thence,
# Nearest to such: underlines, biomass, pranksters, deux, tallis, ancyra, cai, paulinus,
# Nearest to have: celeste, berle, organised, src, brink, mensheviks, cyc, destruction,
# Nearest to if: phonation, imine, interceptor, tatian, manager, accomplishing, peacekeeping, agenda,
# Nearest to state: jewry, diffie, patron, jeremiah, homophobic, fortuna, aorist, draws,
# Nearest to when: clausewitz, inspirations, sst, pharmacies, fretted, hypothetical, blitz, lain,
# Nearest to years: specialization, assumed, tagore, canby, darwin, yachts, gallium, tired,
# Average loss at step 2000: 4.100527
# Average loss at step 4000: 3.563408
# Average loss at step 6000: 3.392113
# Average loss at step 8000: 3.244157
# Average loss at step 10000: 3.180663
# Nearest to will: can, may, would, could, should, cilia, grahame, feud,
# Nearest to its: their, his, the, some, ffff, ancillary, pockets, dentists,
# Nearest to he: it, she, they, who, cuff, there, acoustic, jovian,
# Nearest to american: british, bilingualism, angus, ambivalence, biographical, orthographic, french, proclaiming,
# Nearest to only: scholz, browsers, penetrated, swordfish, seafarers, almoravid, reached, assumed,
# Nearest to into: from, andersen, using, tonal, by, jannah, with, firstnode,
# Nearest to be: have, been, is, was, accountants, trumbo, were, take,
# Nearest to in: on, at, through, from, segmentata, during, with, of,
# Nearest to their: his, its, her, the, soddy, some, islamist, accumulator,
# Nearest to there: it, they, husky, he, which, taro, bickering, johnston,
# Nearest to such: well, underlines, known, sforza, far, mos, wasteful, raspberry,
# Nearest to have: had, has, be, were, billy, are, conspirators, wrench,
# Nearest to if: agenda, imine, allowed, aussie, claws, adler, claim, dispensing,
# Nearest to state: weill, rond, dielectric, jeremiah, subgenus, largest, stitched, homophobic,
# Nearest to when: ateneo, though, linnaean, distribute, keenan, kenny, armalite, tumors,
# Nearest to years: morally, gallium, lund, convincing, tired, days, tagore, kingman,
# Average loss at step 12000: 3.205432
# Average loss at step 14000: 3.153506
# Average loss at step 16000: 3.177308
# Average loss at step 18000: 3.123864
# Average loss at step 20000: 2.990066
# Nearest to will: can, may, would, could, should, must, cannot, might,
# Nearest to its: their, his, her, the, hugo, lizard, oldenburg, meadows,
# Nearest to he: she, it, they, there, who, initially, i, eventually,
# Nearest to american: british, bilingualism, siggraph, catamarans, niggle, german, ambivalence, installations,
# Nearest to only: colchester, swordfish, first, alessandro, scholz, shattering, seafarers, latter,
# Nearest to into: from, through, using, by, andersen, pretensions, crows, back,
# Nearest to be: been, have, being, morricone, is, are, swedes, trumbo,
# Nearest to in: of, during, lagged, on, among, tyson, asymptomatic, bev,
# Nearest to their: its, his, her, the, some, soddy, any, soccer,
# Nearest to there: they, it, he, she, who, taro, often, which,
# Nearest to such: well, known, these, mos, many, underlines, carthaginians, tar,
# Nearest to have: had, has, were, are, be, billy, conspirators, refer,
# Nearest to if: when, where, imaging, agenda, though, postponed, mpc, claim,
# Nearest to state: weill, government, stitched, rides, dielectric, subgenus, ganymede, entente,
# Nearest to when: if, before, after, where, though, keenan, but, linnaean,
# Nearest to years: days, convincing, year, morally, lehrer, tired, msc, tenochtitlan,
# Average loss at step 22000: 3.072376
# Average loss at step 24000: 3.039511
# Average loss at step 26000: 2.995676
# Average loss at step 28000: 3.029619
# Average loss at step 30000: 3.008059
# Nearest to will: would, may, could, can, should, must, cannot, might,
# Nearest to its: their, his, her, the, lizard, continuations, oldenburg, bolden,
# Nearest to he: she, it, they, there, who, never, initially, eventually,
# Nearest to american: british, german, italian, australian, french, siggraph, bilingualism, chalice,
# Nearest to only: halen, shattering, hickman, soaring, vaudeville, swordfish, colchester, loos,
# Nearest to into: through, from, within, andersen, expanses, under, using, firstnode,
# Nearest to be: been, being, morricone, have, become, mason, is, refer,
# Nearest to in: within, during, of, on, until, among, at, sooty,
# Nearest to their: its, his, her, the, soddy, whose, our, these,
# Nearest to there: they, it, he, she, now, we, taro, however,
# Nearest to such: well, these, known, many, mos, reformists, ongoing, carthaginians,
# Nearest to have: had, has, are, were, refer, be, include, having,
# Nearest to if: when, where, though, before, imaging, after, while, mpc,
# Nearest to state: government, weill, stitched, confronts, states, stu, dielectric, wry,
# Nearest to when: if, before, after, because, where, while, linnaean, although,
# Nearest to years: days, times, decades, year, months, seconds, weeks, minstrel,
# Average loss at step 32000: 2.825445
# Average loss at step 34000: 2.951043
# Average loss at step 36000: 2.941660
# Average loss at step 38000: 2.939911
# Average loss at step 40000: 2.932486
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to its: their, his, her, the, our, lizard, your, cheung,
# Nearest to he: she, it, they, there, who, costas, eiga, we,
# Nearest to american: british, italian, indian, german, european, australian, chalice, french,
# Nearest to only: always, halen, vaudeville, soaring, avenged, latter, best, shattering,
# Nearest to into: through, from, using, within, under, with, crows, andersen,
# Nearest to be: been, being, become, have, morricone, remain, produce, wikisource,
# Nearest to in: during, within, throughout, until, through, companionship, jolley, horowitz,
# Nearest to their: its, his, her, the, our, my, whose, these,
# Nearest to there: it, they, he, she, we, usually, still, stroustrup,
# Nearest to such: these, well, known, mos, tar, yamaguchi, follows, defined,
# Nearest to have: had, has, were, are, require, be, having, refer,
# Nearest to if: when, though, where, imaging, keitel, before, audition, cannot,
# Nearest to state: columbia, states, toby, government, stitched, jolie, district, schleicher,
# Nearest to when: if, after, before, where, though, linnaean, during, because,
# Nearest to years: days, months, decades, times, weeks, year, centuries, inches,
# Average loss at step 42000: 2.949307
# Average loss at step 44000: 2.960895
# Average loss at step 46000: 2.910588
# Average loss at step 48000: 2.868314
# Average loss at step 50000: 2.852256
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to its: their, his, her, the, our, your, lizard, whose,
# Nearest to he: she, it, they, who, there, initially, christof, we,
# Nearest to american: british, french, italian, german, canadian, australian, stencil, dutch,
# Nearest to only: no, even, shattering, always, amdahl, incarnation, still, true,
# Nearest to into: through, from, under, within, andersen, back, using, pretensions,
# Nearest to be: been, being, have, become, refer, morricone, is, trumbo,
# Nearest to in: during, within, throughout, from, across, of, until, at,
# Nearest to their: its, his, her, your, our, the, whose, my,
# Nearest to there: they, it, he, we, she, usually, alle, now,
# Nearest to such: well, known, these, regarded, follows, mos, shingles, estuaries,
# Nearest to have: had, has, were, be, include, are, refer, remain,
# Nearest to if: when, though, while, where, imaging, since, before, should,
# Nearest to state: states, columbia, jolie, district, government, weill, toby, stitched,
# Nearest to when: if, after, where, before, though, while, during, because,
# Nearest to years: days, decades, months, weeks, seconds, year, centuries, hours,
# Average loss at step 52000: 2.893740
# Average loss at step 54000: 2.866230
# Average loss at step 56000: 2.851062
# Average loss at step 58000: 2.747294
# Average loss at step 60000: 2.825954
# Nearest to will: would, could, can, should, must, may, cannot, might,
# Nearest to its: their, his, her, the, whose, our, your, asin,
# Nearest to he: she, it, they, who, there, eventually, initially, christof,
# Nearest to american: british, italian, canadian, australian, dutch, french, german, english,
# Nearest to only: halen, shattering, still, no, generally, always, currently, usually,
# Nearest to into: through, within, andersen, from, under, back, over, autographs,
# Nearest to be: been, become, have, refer, being, remain, produce, morricone,
# Nearest to in: during, within, throughout, on, lagged, at, until, among,
# Nearest to their: its, his, her, your, our, whose, the, my,
# Nearest to there: they, it, she, we, he, still, alle, stroustrup,
# Nearest to such: well, known, these, act, opposed, regarded, follows, viewed,
# Nearest to have: had, has, were, be, having, are, include, require,
# Nearest to if: when, though, where, while, before, then, since, after,
# Nearest to state: states, government, columbia, jolie, wry, district, pygmies, weill,
# Nearest to when: if, after, where, during, before, while, though, although,
# Nearest to years: days, decades, months, weeks, seconds, times, year, centuries,
# Average loss at step 62000: 2.838578
# Average loss at step 64000: 2.773248
# Average loss at step 66000: 2.761963
# Average loss at step 68000: 2.715312
# Average loss at step 70000: 2.784285
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to its: their, his, the, her, whose, our, soddy, lizard,
# Nearest to he: she, it, they, who, there, initially, quickly, eventually,
# Nearest to american: british, australian, canadian, italian, african, holley, dutch, indian,
# Nearest to only: shattering, certainly, mongoloid, halen, all, latter, always, priors,
# Nearest to into: through, within, from, under, andersen, back, godless, between,
# Nearest to be: been, become, have, being, achieve, refer, is, morricone,
# Nearest to in: within, during, throughout, under, on, among, since, of,
# Nearest to their: his, its, her, your, our, whose, the, my,
# Nearest to there: they, it, he, we, she, alle, stroustrup, here,
# Nearest to such: known, well, these, regarded, follows, act, defined, opposed,
# Nearest to have: had, has, include, be, having, are, were, require,
# Nearest to if: when, though, where, donoghue, imaging, before, because, nicodemus,
# Nearest to state: states, government, columbia, jolie, wry, district, subgenus, kellogg,
# Nearest to when: if, while, after, before, though, although, where, during,
# Nearest to years: days, decades, months, weeks, year, seconds, centuries, times,
# Average loss at step 72000: 2.793508
# Average loss at step 74000: 2.646947
# Average loss at step 76000: 2.801880
# Average loss at step 78000: 2.822058
# Average loss at step 80000: 2.781874
# Nearest to will: would, can, could, should, must, might, cannot, may,
# Nearest to its: their, his, her, whose, the, our, your, unfamiliar,
# Nearest to he: she, it, they, who, there, we, i, initially,
# Nearest to american: british, italian, australian, canadian, german, african, european, indian,
# Nearest to only: shattering, just, no, latter, always, either, pregnant, soaring,
# Nearest to into: through, within, from, back, curtailing, andersen, crater, godless,
# Nearest to be: become, been, have, achieve, produce, refer, being, get,
# Nearest to in: within, during, on, throughout, near, until, at, under,
# Nearest to their: its, his, her, your, our, whose, the, my,
# Nearest to there: they, it, we, he, alle, now, still, baasha,
# Nearest to such: well, known, these, certain, follows, act, classified, viewed,
# Nearest to have: had, has, were, are, include, contain, having, require,
# Nearest to if: though, when, where, weidman, although, ll, because, before,
# Nearest to state: states, government, columbia, republic, district, toby, wry, weill,
# Nearest to when: although, before, after, if, though, while, during, where,
# Nearest to years: days, months, decades, weeks, seconds, year, centuries, minutes,
# Average loss at step 82000: 2.669528
# Average loss at step 84000: 2.770679
# Average loss at step 86000: 2.734691
# Average loss at step 88000: 2.750911
# Average loss at step 90000: 2.730524
# Nearest to will: would, can, could, should, must, cannot, may, might,
# Nearest to its: their, his, the, whose, her, our, cheung, lizard,
# Nearest to he: she, it, they, there, who, we, christof, moore,
# Nearest to american: british, african, australian, italian, indian, european, canadian, german,
# Nearest to only: shattering, until, just, pregnant, certainly, seafarers, always, either,
# Nearest to into: through, from, within, aorta, godless, instantaneous, pretensions, ahead,
# Nearest to be: been, become, being, refer, get, have, achieve, trumbo,
# Nearest to in: during, on, within, throughout, near, at, until, through,
# Nearest to their: its, his, her, your, our, whose, my, soddy,
# Nearest to there: they, it, we, she, he, alle, still, however,
# Nearest to such: well, these, known, follows, act, serve, viewed, possible,
# Nearest to have: had, has, were, require, are, having, contain, be,
# Nearest to if: though, when, before, where, although, because, did, nicodemus,
# Nearest to state: government, states, district, wry, toby, vitae, republic, city,
# Nearest to when: if, though, after, where, before, although, while, during,
# Nearest to years: days, decades, weeks, months, year, minutes, seconds, centuries,
# Average loss at step 92000: 2.677241
# Average loss at step 94000: 2.719799
# Average loss at step 96000: 2.701372
# Average loss at step 98000: 2.362549
# Average loss at step 100000: 2.400719
# Nearest to will: would, can, could, must, should, might, cannot, may,
# Nearest to its: their, his, her, whose, lizard, the, our, cheung,
# Nearest to he: she, they, it, there, who, we, initially, quickly,
# Nearest to american: english, australian, canadian, british, german, italian, jim, univ,
# Nearest to only: shattering, last, vaudeville, just, first, latter, certainly, pregnant,
# Nearest to into: through, within, from, beyond, under, curtailing, back, instantaneous,
# Nearest to be: become, been, have, being, get, achieve, refer, is,
# Nearest to in: during, at, near, within, throughout, despite, around, outside,
# Nearest to their: his, its, her, your, our, my, whose, these,
# Nearest to there: they, he, it, we, she, here, alle, still,
# Nearest to such: well, known, these, many, regarded, serve, act, cited,
# Nearest to have: had, has, having, were, include, require, contain, are,
# Nearest to if: when, though, follows, before, msm, where, because, considers,
# Nearest to state: states, government, district, territory, wry, republic, candidate, neri,
# Nearest to when: if, after, before, though, while, where, although, during,
# Nearest to years: days, weeks, months, decades, minutes, seconds, year, hours,

# %%
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
plot(two_d_embeddings, words)
